# %% [markdown]
# # "Matplotlib"
# > ""
#
# - author: Christopher Thiemann
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [python, plotting]
# - hide: false
# - search_exclude: true

# %%
#hide

import numpy as np
import scipy as sp

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import pandas as pd

# %% [markdown]
# ## Setting styles

# %%
with plt.style.context('fivethirtyeight'):
    plot()

# %% [markdown]
# You can even use a URL pounint to the style sheet. Source https://twitter.com/d_haitz/status/1277585108032258049

# %%
with plt.style.context('https://raw.githubusercontent.com/nickteff/EconomistStyle/master/theeconomist.mplstyle'):
    plot()

# %% [markdown]
# ## Adjusting the axis and fig parameters
#
# We can customize a lot of the figure like the label, or title via the set command.

# %%
x = np.linspace(-10, 10, 100)
with plt.style.context('fivethirtyeight'):

    fig_kws = { 'facecolor': 'red', 
						'figsize':(14, 5),
						'edgecolor':'k',
						'linewidth':0,
						'frameon': True,
						'tight_layout': False,
						'constrained_layout': True,
			}

    fig, axes = plt.subplots(**fig_kws)

    axes.set(xlabel = 'X-Axis',
             ylabel = "sine function",
             title = "Demonstration of a title",
             xlim=(-5, 5),
             ylim = (-.9, .9),
             xticks = [-.2,.2],
			 xticklabels =['a', 'b'],
			 yticks = [-.2,.2],
			 yticklabels =['a', 'b'],
             facecolor = 'black',
             yscale = 'linear', #log
			 xscale = 'linear'
             )
    

    axes.plot(x, np.sin(x))

# %% [markdown]
# ## Helper Functions

# %%
def plot():
    "Simple function to generate some plots."

    fig, axes = plt.subplots(1, 3, tight_layout = True, figsize = (15, 5))
    x = np.linspace(0, 5, 100)

    for i in range(1, 4):
        axes[0].plot(x, x ** i, linewidth = 5)

    xx = np.random.randn(100)
    xx.sort()
    axes[1].plot(xx, xx.cumsum())

    axes[2].hist(np.random.normal(size = 100))

# %% [markdown]
# ## Plot for the Blog Post

# %% [markdown]
# ## Sources
#
#
# - [x] https://twitter.com/matplotlib/status/1256364300492513281
#
# - [ ] https://brohrer.github.io/matplotlib_ticks.html
#
# - [ ] https://t.co/GJLME5PuOC?amp=1
#
# - [ ] https://github.com/awslabs/autogluon
#
# - [ ] https://github.com/matplotlib/cheatsheets
#
# - [ ] http://matplotlib-style-configurator.herokuapp.com/
#
# - [ ] https://github.com/dhaitz/matplotlib-stylesheets
#
# - [ ] https://twitter.com/HillairetJulien/status/1291298772832657409
#
# - [ ] https://twitter.com/MilesCranmer/status/1290800078702116869
#
# - [x] https://twitter.com/d_haitz/status/1277585108032258049
#
# - [ ] https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
#
# - [ ] https://github.com/Phlya/adjustText
# - [ ] https://github.com/matplotlib/ipympl

# %% [markdown]
# ## References

# %% [markdown]
# {% bibliography --cited %}
